# %%
# Example of syntax error

print 'hello world'
# Out:
#   Cell In[1], line 3
#     print 'hello world'
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('hello world')?

# %%
a = 5
if a==3
    print('hello')
# Out:
#   Cell In[2], line 2
#     if a==3
#            ^
# SyntaxError: invalid syntax

# %%
a = 5 
iff a == 3:
    print('hello')
# Out:
#   Cell In[3], line 2
#     iff a == 3:
#         ^
# SyntaxError: invalid syntax

# %%
a = 5
if a == 3:
print('hello')
# Out:
#   Cell In[4], line 3
#     print('hello')
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# # how to handle Exceptions

# %%
# Why is it important to handle exceptions
# how to handle exceptions
# -> try except block

# %%
with open('sample.txt', 'w') as f:
    f.write('hello world')

# %%
# try catch demo 
try:
    with open('sample1.txt', 'r') as f:
        print(f.read())

except:
    print('sorry file not found')
# Out:
# sorry file not found

# %%
# catching specific exception
try:
    f = open('sample.txt', 'r')
    print(f.read())
    print(m)
except FileNotFoundError:
    print('file not found')
except NameError:
    print('Variable not defined')

except Exception as e:
    print(e)
# Out:
# hello world
# Variable not defined

# %%
try:
    f = open('sample.txt','r')
except FileNotFoundError:
    print('file nai mili')
except Exception:
    print('kuch to lafda hai')
else:
    print(f.read())

finally:
    print('ye to print hi hoga hi')
# Out:
# hello world
# ye to print hi hoga hi

# %%
# finally

# %%
# raise exception
raise NameError('try again')
# java
# try -> try
# except -> catch
# raise -> throw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # raise exception
# ----> 2 raise NameError('try again')
#
# NameError: try again

# %%
class Bank:
    def __init__(self,balance):
        self.balance = balance

    def withdraw(self,amount):
        if amount < 0:
            raise Exception('amount cannot be -ve')
        if self.balance < amount:
            raise Exception('paisa nai hai tere pass')
        self.balance = self.balance - amount

obj = Bank(10000)

try:
    obj.withdraw(15000)
except Exception as e:
    print(e)
else:
    print(obj.balance)
# Out:
# paisa nai hai tere pass

# %%
class MyException(Exception):
    def __init__(self,message):
        print(message)
    
class Bank:
    def __init__(self,balance):
        self.balance = balance

    def withdraw(self,amount):
        if amount < 0:
            raise MyException('amount cannot be -ve')
        if self.balance < amount:
            raise MyException('paisa nai hai tere pass')
        self.balance = self.balance - amount

obj = Bank(10000)

try:
    obj.withdraw(15000)
except MyException as e:
    pass
else:
    print(obj.balance)
# Out:
# paisa nai hai tere pass
