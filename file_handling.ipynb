# %%
# case 1- if the file is not present

f = open('sample', 'w')
f.write('Hello world')
f.close()

# %%
f = open('sample1.text','w')
f.write('Hello world')
f.write('\nhow are you')
f.close()

# %%
f = open('sample','w')
f.write('salmaan khan')
f.close()

# %%
f = open('sample1.text', 'a')
f.write('\nI am fine')
f.close()

# %%
L = ['hello\n','hi\n','how are you\n','i am fine']
f= open('sample', 'w')
f.writelines(L)
f.close()

# %%
# reading from files
f = open(r"E:\file_handling\sample",'r')
s= f.read()
print(s)
f.close()
# Out:
# hello
# hi
# how are you
# i am fine

# %%
# reading from files
f = open(r"E:\file_handling\sample",'r')
s= f.read(10)
print(s)
f.close()
# Out:
# hello
# hi
# h

# %%
# reading from files
f = open(r"E:\file_handling\sample",'r')
print(f.readline(),end = '')
print(f.readline(),end = '')

f.close()
# Out:
# hello
# hi

# %%
f = open(r"E:\file_handling\sample",'r')

while True:
    data = f.readline()

    if data == '':
        break
    else:
        print(data,end = '')

f.close()
# Out:
# hello
# hi
# how are you
# i am fine

# %%
# with

with open('sample1.text','') as f:
    f.write('salmaan bhai')

# %%
f.write('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f.write('hello')
#
# ValueError: I/O operation on closed file.

# %%
with open('sample1.text', 'r') as f:
    print(f.read())
# Out:
# salmaan bhai

# %%
with open(r"E:\file_handling\sample", 'r') as f:
    print(f.read(10))
    print(f.read(10))
# Out:
# hello
# hi
# h
# ow are you

# %%
big_L = ['Hello world' for i in range(1000)]

with open('big.txt','w') as f:
    f.writelines(big_L)

# %%
with open('big.txt', 'r') as f:

    chunk_size = 200

    while len(f.read(chunk_size))> 0:
        print(f.read(chunk_size),end = '*****')
        f.read(chunk_size)
# Out:
# llo worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHell*****rldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worl*****lo worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello*****ldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello world*****o worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello worldHello 
# ...

# %%
# seek and tell function

with open(r"E:\file_handling\sample", 'r') as f:
    print(f.read(10))
    print(f.tell())
    f.seek(0)
    print(f.read(10))
    print(f.tell())
# Out:
# hello
# hi
# h
# 12
# hello
# hi
# h
# 12

# %%
with open(r"E:\file_handling\sample", 'w') as f:
    f.write('hello')
    f.seek(0)
    f.write('Xa')
    f.close()

# %%
with open(r"E:\file_handling\pic\sonu.jpg", 'rb') as f:
    with open('pic1.jpg', 'wb') as wf:
        wf.write(f.read())

# %%
with open('sample.txt', 'w') as f:
    f.write('5')

# %%
with open(r"E:\file_handling\sample.txt", 'r') as f:
    print(int(f.read()) +5)
# Out:
# 10

# %%
d = {
    'name': 'Tanish',
    'age': 33,
    'gender': 'male'
}

with open(r"E:\file_handling\sample.txt",'w') as f:
    f.write(str(d))

# %%
with open(r"E:\file_handling\sample.txt",'r') as f:
    print(dict((f.read()))
# Out:
#   Cell In[8], line 2
#     print(dict((f.read()))
#                           ^
# SyntaxError: unexpected EOF while parsing

# %%
import json

L = [1,2,3,4]

with open('demo.json', 'w') as f:
    json.dump(L,f)

# %%
d = {
    'name': 'Tanish',
    'age': 33,
    'gender': 'male'
}

with open('demo.json', 'w') as f:
    json.dump(d,f,indent= 4)

# %%
import json

with open('demo.json', 'r') as f:
    print(json.load(f))
# Out:
# {'name': 'Tanish', 'age': 33, 'gender': 'male'}

# %% [markdown]
# # serializing and Deserializing custom objects

# %%
class Person:
    def __init__(self,fname,lname,age,gender):
        self.fname = fname
        self.lname = lname
        self.age = age
        self.gender = gender

# %%
person = Person('Tanish','Sonu',33, 'male')

# %%
import json

def show_object(person):
    if isinstance(person,Person):
        return "{} {} age -> {} gender -> {}".format(person.fname,person.lname,person.age,person.gender)

with open('demo.json','w') as f:
    json.dump(person,f,default = show_object)

# %%
import json

def show_object(person):
    if isinstance(person,Person):
        return  {'name':person.fname+ ' ' + person.lname,   'age':person.age , 'gender':  person.gender}

with open('demo.json','w') as f:
    json.dump(person,f,default = show_object)

# %%
import json

with open('demo.json', 'r') as f:
    d =json.load(f)
    print(d)
    print(type(d))
# Out:
# {'name': 'Tanish Sonu', 'age': 33, 'gender': 'male'}
# <class 'dict'>

# %%
# pickle

class Person:
    def __init__(self, name,age):
        self.name = name
        self.age = age

    def display_info(self):
        print('Hi my name', self.name, 'and I am',self.age, 'years old')

# %%
p = Person('tanish',33)

# %%
import pickle

# %%
with open('person.pk1','wb') as f:
    pickle.dump(p,f)
